# %% [markdown]
# # PiML Toolbox: High-code Demo for CaliforniaHousing Data
#
# This example notebook demonstrates how to use PiML with its high-code APIs for developing machine learning models for the CaliforniaHousing data, which consists of 20,640 samples and 9 features, fetched by sklearn.datasets (see details here). PiML can load three versions of this data, including _raw, _trim1 (trimming only AveOccup) and _trim2 (trimming AveRooms, AveBedrms, Population and AveOccup). The _trim2 version is used in this example.
#
# The response MedHouseVal (median house price per block in log scale) is continuous and it is a regression problem.

# %% [markdown]
# # Stage 0: Install PiML package on Google Colab
#
# 1. Run `!pip install piml` to install the latest version of PiML. It requires V0.2 or above to use high-code APIs.
# 2. In Colab, you'll need restart the runtime in order to use newly installed PiML version.

# %%
#!pip install piml

# %%
from piml import Experiment
exp = Experiment(highcode_only=True)

# %% [markdown]
# # Stage 1: Initialize an experiment, Load and Prepare data

# %%
exp.data_loader(data='CaliforniaHousing_trim2')
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# 0        -122.23        4.526
# 1        -122.22        3.585
# 2        -122.24        3.521
# 3        -122.25        3.413
# 4        -122.25        3.422
# ...          ...          ...
# 20635    -121.09        0.781
# 20636    -121.21        0.771
# 20637    -121.22        0.923
# 20638    -121.32        0.847
# 20639    -121.24        0.894
#
# [20640 rows x 9 columns]

# %%
exp.data_summary(feature_exclude=[])
# Out:
# <style type="text/css">
# </style>
# <table id="T_15f9e" style='display:inline'>
#   <caption>Numerical Attributes</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_15f9e_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_15f9e_level0_col1" class="col_heading level0 col1" >n_missing</th>
#       <th id="T_15f9e_level0_col2" class="col_heading level0 col2" >mean</th>
#       <th id="T_15f9e_level0_col3" class="col_heading level0 col3" >std</th>
#       <th id="T_15f9e_level0_col4" class="col_heading level0 col4" >min</th>
#       <th id="T_15f9e_level0_col5" class="col_heading level0 col5" >q1</th>
#       <th id="T_15f9e_level0_col6" class="col_heading level0 col6" >median</th>
#       <th id="T_15f9e_level0_col7" class="col_heading level0 col7" >q3</th>
#       <th id="T_15f9e_level0_col8" class="col_heading level0 col8" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15f9e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_15f9e_row0_col0" class="data row0 col0" >MedInc</td>
#       <td id="T_15f9e_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_15f9e_row0_col2" class="data row0 col2" >3.8707</td>
#       <td id="T_15f9e_row0_col3" class="data row0 col3" >1.8998</td>
#       <td id="T_15f9e_row0_col4" class="data row0 col4" >0.4999</td>
#       <td id="T_15f9e_row0_col5" class="data row0 col5" >2.5634</td>
#       <td id="T_15f9e_row0_col6" class="data row0 col6" >3.5348</td>
#       <td id="T_15f9e_row0_col7" class="data row0 col7" >4.7432</td>
#       <td id="T_15f9e_row0_col8" class="data row0 col8" >15.0001</td>
#     </tr>
#     <tr>
#       <th id="T_15f9e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_15f9e_row1_col0" class="data row1 col0" >HouseAge</td>
#       <td id="T_15f9e_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_15f9e_row1_col2" class="data row1 col2" >28.6395</td>
#       <td id="T_15f9e_row1_col3" class="data row1 col3" >12.5856</td>
#       <td id="T_15f9e_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_15f9e_row1_col5" class="data row1 col5" >18.0000</td>
#       <td id="T_15f9e_row1_col6" class="data row1 col6" >29.0000</td>
#       <td id="T_15f9e_row1_col7" class="data row1 col7" >37.0000</td>
#       <td id="T_15f9e_row1_col8" class="data row1 col8" >52.0000</td>
#     </tr>
#     <tr>
#       <th id="T_15f9e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_15f9e_row2_col0" class="data row2 col0" >AveRooms</td>
#       <td id="T_15f9e_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_15f9e_row2_col2" class="data row2 col2" >5.3070</td>
#       <td id="T_15f9e_row2_col3" class="data row2 col3" >1.2559</td>
#       <td id="T_15f9e_row2_col4" class="data row2 col4" >0.8462</td>
#       <td id="T_15f9e_row2_col5" class="data row2 col5" >4.4407</td>
#       <td id="T_15f9e_row2_col6" class="data row2 col6" >5.2291</td>
#       <td id="T_15f9e_row2_col7" class="data row2 col7" >6.0524</td>
#       <td id="T_15f9e_row2_col8" class="data row2 col8" >8.6100</td>
#     </tr>
#     <tr>
#       <th id="T_15f9e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_15f9e_row3_col0" class="data row3 col0" >AveBedrms</td>
#       <td id="T_15f9e_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_15f9e_row3_col2" class="data row3 col2" >1.0689</td>
#       <td id="T_15f9e_row3_col3" class="data row3 col3" >0.1199</td>
#       <td id="T_15f9e_row3_col4" class="data row3 col4" >0.3333</td>
#       <td id="T_15f9e_row3_col5" class="data row3 col5" >1.0061</td>
#       <td id="T_15f9e_row3_col6" class="data row3 col6" >1.0488</td>
#       <td id="T_15f9e_row3_col7" class="data row3 col7" >1.0995</td>
#       <td id="T_15f9e_row3_col8" class="data row3 col8" >1.5915</td>
#     </tr>
#     <tr>
#       <th id="T_15f9e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_15f9e_row4_col0" class="data row4 col0" >Population</td>
#       <td id="T_15f9e_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_15f9e_row4_col2" class="data row4 col2" >1386.5343</td>
#       <td id="T_15f9e_row4_col3" class="data row4 col3" >905.7698</td>
#       <td id="T_15f9e_row4_col4" class="data row4 col4" >3.0000</td>
#       <td id="T_15f9e_row4_col5" class="data row4 col5" >787.0000</td>
#       <td id="T_15f9e_row4_col6" class="data row4 col6" >1166.0000</td>
#       <td id="T_15f9e_row4_col7" class="data row4 col7" >1725.0000</td>
#       <td id="T_15f9e_row4_col8" class="data row4 col8" >4573.0000</td>
#     </tr>
#     <tr>
#       <th id="T_15f9e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_15f9e_row5_col0" class="data row5 col0" >AveOccup</td>
#       <td id="T_15f9e_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_15f9e_row5_col2" class="data row5 col2" >2.9075</td>
#       <td id="T_15f9e_row5_col3" class="data row5 col3" >0.7117</td>
#       <td id="T_15f9e_row5_col4" class="data row5 col4" >0.6923</td>
#       <td id="T_15f9e_row5_col5" class="data row5 col5" >2.4297</td>
#       <td id="T_15f9e_row5_col6" class="data row5 col6" >2.8181</td>
#       <td id="T_15f9e_row5_col7" class="data row5 col7" >3.2823</td>
#       <td id="T_15f9e_row5_col8" class="data row5 col8" >4.8640</td>
#     </tr>
#     <tr>
#       <th id="T_15f9e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_15f9e_row6_col0" class="data row6 col0" >Latitude</td>
#       <td id="T_15f9e_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_15f9e_row6_col2" class="data row6 col2" >35.6319</td>
#       <td id="T_15f9e_row6_col3" class="data row6 col3" >2.1360</td>
#       <td id="T_15f9e_row6_col4" class="data row6 col4" >32.5400</td>
#       <td id="T_15f9e_row6_col5" class="data row6 col5" >33.9300</td>
#       <td id="T_15f9e_row6_col6" class="data row6 col6" >34.2600</td>
#       <td id="T_15f9e_row6_col7" class="data row6 col7" >37.7100</td>
#       <td id="T_15f9e_row6_col8" class="data row6 col8" >41.9500</td>
#     </tr>
#     <tr>
#       <th id="T_15f9e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_15f9e_row7_col0" class="data row7 col0" >Longitude</td>
#       <td id="T_15f9e_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_15f9e_row7_col2" class="data row7 col2" >-119.5697</td>
#       <td id="T_15f9e_row7_col3" class="data row7 col3" >2.0035</td>
#       <td id="T_15f9e_row7_col4" class="data row7 col4" >-124.3500</td>
#       <td id="T_15f9e_row7_col5" class="data row7 col5" >-121.8000</td>
#       <td id="T_15f9e_row7_col6" class="data row7 col6" >-118.4900</td>
#       <td id="T_15f9e_row7_col7" class="data row7 col7" >-118.0100</td>
#       <td id="T_15f9e_row7_col8" class="data row7 col8" >-114.3100</td>
#     </tr>
#     <tr>
#       <th id="T_15f9e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_15f9e_row8_col0" class="data row8 col0" >MedHouseVal</td>
#       <td id="T_15f9e_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_15f9e_row8_col2" class="data row8 col2" >2.0686</td>
#       <td id="T_15f9e_row8_col3" class="data row8 col3" >1.1540</td>
#       <td id="T_15f9e_row8_col4" class="data row8 col4" >0.1500</td>
#       <td id="T_15f9e_row8_col5" class="data row8 col5" >1.1960</td>
#       <td id="T_15f9e_row8_col6" class="data row8 col6" >1.7970</td>
#       <td id="T_15f9e_row8_col7" class="data row8 col7" >2.6472</td>
#       <td id="T_15f9e_row8_col8" class="data row8 col8" >5.0000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_2cc25" style='display:inline'>
#   <caption>Categorical Attributes</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2cc25_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_2cc25_level0_col1" class="col_heading level0 col1" >n_missing</th>
#       <th id="T_2cc25_level0_col2" class="col_heading level0 col2" >n_unique</th>
#       <th id="T_2cc25_level0_col3" class="col_heading level0 col3" >top1</th>
#       <th id="T_2cc25_level0_col4" class="col_heading level0 col4" >top2</th>
#       <th id="T_2cc25_
# Data Shape:(20640, 9)

# %%
exp.data_prepare(target='MedHouseVal', task_type='regression', test_ratio=0.2, random_state=0)
# Out:
#              Config        Value
# 0  Excluded columns           []
# 1   Target variable  MedHouseVal
# 2     Sample weight         None
# 3         Task type   regression
# 4      Split method       random
# 5        Test ratio          0.2
# 6      Random state            0

# %%
exp.feature_select(method="pfi", threshold=0.9, figsize=(6, 5))

# %%
exp.eda(show='univariate', uni_feature='MedHouseVal', figsize=(6, 5))

# %%
exp.eda(show='bivariate', bi_features=['Longitude', 'Latitude'], figsize=(6, 5))

# %%
exp.eda(show='multivariate', multi_type='correlation_heatmap', figsize=(6, 5))

# %% [markdown]
# # Stage 2. Train intepretable models

# %%
## ReLU-DNN: ReLU Deep Neural Networks with L1-Regularization
from piml.models import ReluDNNRegressor

clf1 = ReluDNNRegressor(hidden_layer_sizes=(40, 40), l1_reg=1e-05,
                        batch_size=500, learning_rate=0.001)
exp.model_train(model=clf1, name='ReLU-DNN')
exp.model_diagnose(model="ReLU-DNN", show='accuracy_table')
# Out:
#           MSE     MAE       R2
#
# Train  0.0143  0.0839   0.7495
# Test   0.0144  0.0848   0.7397
# Gap    0.0002  0.0009  -0.0098

# %%
## GAMI-Net: GAM-Neural Networks with Structured Interactions
from piml.models import GAMINetRegressor

clf2 = GAMINetRegressor(interact_num=10, loss_threshold=0.01,
                        subnet_size_main_effect=[20],
                        subnet_size_interaction=[20,20])
exp.model_train(model=clf2, name='GAMI-Net')
exp.model_diagnose(model="GAMI-Net", show='accuracy_table')

# %%
## EBM: Explainable Boosting Machine from MS Research
from piml.models import ExplainableBoostingRegressor

clf3 = ExplainableBoostingRegressor(interactions=10, random_state=0)
exp.model_train(model=clf3, name='EBM')
exp.model_diagnose(model="EBM", show='accuracy_table')

# %%
exp.model_compare(models=['ReLU-DNN', 'GAMI-Net', 'EBM'], show='accuracy_plot', metric="MSE", figsize=(6, 5))

# %% [markdown]
# # Stage 3. Explain and Interpret

# %% [markdown]
# ## Post-hoc Explaination: Global and Local Methods

# %%
exp.model_explain(model='GAMI-Net', show='pfi', figsize=(6, 5))

# %%
exp.model_explain(model='GAMI-Net', show='pdp', uni_feature='Latitude', figsize=(6, 5))

# %%
exp.model_explain(model='GAMI-Net', show='ice', uni_feature='Latitude', figsize=(6, 5))

# %%
exp.model_explain(model='GAMI-Net', show='ale', bi_features=['Longitude', 'Latitude'], figsize=(6, 5))

# %%
exp.model_explain(model='GAMI-Net', show='shap_fi', sample_size=20, figsize=(6, 5))

# %%
exp.model_explain(model='GAMI-Net', show='shap_summary', sample_size=20, figsize=(6, 5))

# %%
exp.model_explain(model='GAMI-Net', show='lime', sample_id=0, figsize=(6, 5))

# %%
exp.model_explain(model='EBM', show='shap_waterfall', sample_id=0, figsize=(6, 5))

# %% [markdown]
# ## Inherent Interpretation: Global and Local Methods

# %%
exp.model_interpret(model='GAMI-Net', show='global_fi', figsize=(6, 5))

# %%
exp.model_interpret(model='GAMI-Net', show='global_effect_plot', uni_feature='MedInc', figsize=(6, 5))

# %%
exp.model_interpret(model='GAMI-Net', show='global_effect_plot',
                    bi_features=['Longitude', 'Latitude'], figsize=(6, 5))

# %%
exp.model_interpret(model='GAMI-Net', show='local_fi', sample_id=0, figsize=(6, 5))

# %% [markdown]
# # Stage 4. Diagnose and Compare

# %%
exp.model_diagnose(model='GAMI-Net', show='accuracy_table')

# %%
exp.model_diagnose(model='GAMI-Net', show='accuracy_residual', show_feature='MedInc', figsize=(6, 5))

# %%
exp.model_diagnose(model='GAMI-Net', show='weakspot', slice_features=['MedInc'],
                   slice_method='tree', threshold=1.2, min_samples=20, figsize=(6, 5))

# %%
exp.model_diagnose(model='GAMI-Net', show='weakspot', slice_features=['Longitude', 'Latitude'],
                   slice_method='histogram', threshold=1.2, min_samples=20, figsize=(6, 5))

# %%
exp.model_diagnose(model='GAMI-Net', show='weakspot', slice_features=['Longitude', 'Latitude'],
                   slice_method='histogram', threshold=1.2, min_samples=20, figsize=(6, 5))

# %%
exp.model_diagnose(model='GAMI-Net', show='overfit', slice_features=['MedInc'],
                   slice_method='histogram', threshold=1.2, min_samples=20, figsize=(6, 5))

# %%
exp.model_diagnose(model='GAMI-Net', show='reliability_table', alpha=0.1)

# %%
exp.model_diagnose(model='GAMI-Net', show='robustness_perf', perturb_features=["Longitude", "Latitude"],
                   perturb_size=0.1, figsize=(6, 5))

# %%
exp.model_diagnose(model='GAMI-Net', show='resilience_perf', figsize=(6, 5))

# %%
exp.model_diagnose(model='GAMI-Net', show='resilience_shift_density', immu_feature='MedInc',
                   show_feature='MedInc', alpha=0.1, figsize=(6, 5))

# %%
exp.model_compare(models=['ReLU-DNN', 'GAMI-Net', 'EBM'], show='reliability_coverage', figsize=(6, 5))

# %%
exp.model_compare(models=['ReLU-DNN', 'GAMI-Net', 'EBM'], show='reliability_bandwidth', figsize=(6, 5))

# %%
exp.model_compare(models=['ReLU-DNN', 'GAMI-Net', 'EBM'], show='robustness_perf', figsize=(6, 5))

# %%
exp.model_compare(models=['ReLU-DNN', 'GAMI-Net', 'EBM'], show='robustness_perf_worst', alpha=0.3, figsize=(6, 5))

# %%
exp.model_compare(models=['ReLU-DNN','GAMI-Net', 'EBM'], show='resilience_perf', figsize=(6, 5))

# %%
exp.model_compare(models=['ReLU-DNN', 'GAMI-Net', 'EBM'], show='resilience_distance', figsize=(6, 5))
