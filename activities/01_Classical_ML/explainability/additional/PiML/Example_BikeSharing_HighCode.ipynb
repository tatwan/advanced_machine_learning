# %% [markdown]
# # PiML Toolbox: High-code Demo for BikeSharing Data
#
# This example notebook demonstrates how to use PiML with its high-code APIs for developing machine learning models for the BikeSharing data from UCI repository, which consists of 17,389 samples of hourly counts of rental bikes in Capital bikeshare system; see details [here](https://archive.ics.uci.edu/ml/datasets/bike+sharing+dataset).
#
# The response `cnt` (hourly bike rental counts) is continuous and it is a regression problem.

# %% [markdown]
# # Install PiML Toolbox
#
# 1. Run `!pip install piml` to install the latest version of PiML
# 2. In Google Colab, we need restart the runtime in order to use newly installed version

# %%
#!pip install piml

# %%
from piml import Experiment
exp = Experiment(highcode_only=True)

# %% [markdown]
# # Load and Prepare Data

# %%
# Choose BikeSharing
exp.data_loader(data='BikeSharing')
# Out:
#        season  yr  mnth  hr  holiday  weekday  workingday  weathersit  temp  \
# 0           1   0     1   0        0        6           0           1  0.24
# 1           1   0     1   1        0        6           0           1  0.22
# 2           1   0     1   2        0        6           0           1  0.22
# 3           1   0     1   3        0        6           0           1  0.24
# 4           1   0     1   4        0        6           0           1  0.24
# ...       ...  ..   ...  ..      ...      ...         ...         ...   ...
# 17374       1   1    12  19        0        1           1           2  0.26
# 17375       1   1    12  20        0        1           1           2  0.26
# 17376       1   1    12  21        0        1           1           1  0.26
# 17377       1   1    12  22        0        1           1           1  0.26
# 17378       1   1    12  23        0        1           1           1  0.26
#
#         atemp   hum  windspeed  cnt
# 0      0.2879  0.81     0.0000   16
# 1      0.2727  0.80     0.0000   40
# 2      0.2727  0.80     0.0000   32
# 3      0.2879  0.75     0.0000   13
# 4      0.2879  0.75     0.0000    1
# ...       ...   ...        ...  ...
# 17374  0.2576  0.60     0.1642  119
# 17375  0.2576  0.60     0.1642   89
# 17376  0.2576  0.60     0.1642   90
# 17377  0.2727  0.56     0.1343   61
# 17378  0.2727  0.65     0.1343   49
#
# [17379 rows x 13 columns]

# %%
# Exclude these features one-by-one: "season", "workingday", "atemp" (highly correlated with others)
exp.data_summary(feature_exclude=["season", "workingday", "atemp"])
# Out:
# <style type="text/css">
# #T_f10a8_row4_col0, #T_f10a8_row4_col1, #T_f10a8_row4_col2, #T_f10a8_row4_col3, #T_f10a8_row4_col4, #T_f10a8_row4_col5, #T_f10a8_row4_col6, #T_f10a8_row4_col7, #T_f10a8_row4_col8 {
#   background-color: grey;
# }
# </style>
# <table id="T_f10a8" style='display:inline'>
#   <caption>Numerical Attributes</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f10a8_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_f10a8_level0_col1" class="col_heading level0 col1" >n_missing</th>
#       <th id="T_f10a8_level0_col2" class="col_heading level0 col2" >mean</th>
#       <th id="T_f10a8_level0_col3" class="col_heading level0 col3" >std</th>
#       <th id="T_f10a8_level0_col4" class="col_heading level0 col4" >min</th>
#       <th id="T_f10a8_level0_col5" class="col_heading level0 col5" >q1</th>
#       <th id="T_f10a8_level0_col6" class="col_heading level0 col6" >median</th>
#       <th id="T_f10a8_level0_col7" class="col_heading level0 col7" >q3</th>
#       <th id="T_f10a8_level0_col8" class="col_heading level0 col8" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f10a8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f10a8_row0_col0" class="data row0 col0" >mnth</td>
#       <td id="T_f10a8_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_f10a8_row0_col2" class="data row0 col2" >6.5378</td>
#       <td id="T_f10a8_row0_col3" class="data row0 col3" >3.4388</td>
#       <td id="T_f10a8_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_f10a8_row0_col5" class="data row0 col5" >4.0000</td>
#       <td id="T_f10a8_row0_col6" class="data row0 col6" >7.0000</td>
#       <td id="T_f10a8_row0_col7" class="data row0 col7" >10.0000</td>
#       <td id="T_f10a8_row0_col8" class="data row0 col8" >12.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f10a8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f10a8_row1_col0" class="data row1 col0" >hr</td>
#       <td id="T_f10a8_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_f10a8_row1_col2" class="data row1 col2" >11.5468</td>
#       <td id="T_f10a8_row1_col3" class="data row1 col3" >6.9144</td>
#       <td id="T_f10a8_row1_col4" class="data row1 col4" >0.0000</td>
#       <td id="T_f10a8_row1_col5" class="data row1 col5" >6.0000</td>
#       <td id="T_f10a8_row1_col6" class="data row1 col6" >12.0000</td>
#       <td id="T_f10a8_row1_col7" class="data row1 col7" >18.0000</td>
#       <td id="T_f10a8_row1_col8" class="data row1 col8" >23.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f10a8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f10a8_row2_col0" class="data row2 col0" >weekday</td>
#       <td id="T_f10a8_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_f10a8_row2_col2" class="data row2 col2" >3.0037</td>
#       <td id="T_f10a8_row2_col3" class="data row2 col3" >2.0058</td>
#       <td id="T_f10a8_row2_col4" class="data row2 col4" >0.0000</td>
#       <td id="T_f10a8_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_f10a8_row2_col6" class="data row2 col6" >3.0000</td>
#       <td id="T_f10a8_row2_col7" class="data row2 col7" >5.0000</td>
#       <td id="T_f10a8_row2_col8" class="data row2 col8" >6.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f10a8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f10a8_row3_col0" class="data row3 col0" >temp</td>
#       <td id="T_f10a8_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_f10a8_row3_col2" class="data row3 col2" >0.4970</td>
#       <td id="T_f10a8_row3_col3" class="data row3 col3" >0.1926</td>
#       <td id="T_f10a8_row3_col4" class="data row3 col4" >0.0200</td>
#       <td id="T_f10a8_row3_col5" class="data row3 col5" >0.3400</td>
#       <td id="T_f10a8_row3_col6" class="data row3 col6" >0.5000</td>
#       <td id="T_f10a8_row3_col7" class="data row3 col7" >0.6600</td>
#       <td id="T_f10a8_row3_col8" class="data row3 col8" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f10a8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f10a8_row4_col0" class="data row4 col0" >atemp</td>
#       <td id="T_f10a8_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_f10a8_row4_col2" class="data row4 col2" >0.4758</td>
#       <td id="T_f10a8_row4_col3" class="data row4 col3" >0.1719</td>
#       <td id="T_f10a8_row4_col4" class="data row4 col4" >0.0000</td>
#       <td id="T_f10a8_row4_col5" class="data row4 col5" >0.3333</td>
#       <td id="T_f10a8_row4_col6" class="data row4 col6" >0.4848</td>
#       <td id="T_f10a8_row4_col7" class="data row4 col7" >0.6212</td>
#       <td id="T_f10a8_row4_col8" class="data row4 col8" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f10a8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f10a8_row5_col0" class="data row5 col0" >hum</td>
#       <td id="T_f10a8_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_f10a8_row5_col2" class="data row5 col2" >0.6272</td>
#       <td id="T_f10a8_row5_col3" class="data row5 col3" >0.1929</td>
#       <td id="T_f10a8_row5_col4" class="data row5 col4" >0.0000</td>
#       <td id="T_f10a8_row5_col5" class="data row5 col5" >0.4800</td>
#       <td id="T_f10a8_row5_col6" class="data row5 col6" >0.6300</td>
#       <td id="T_f10a8_row5_col7" class="data row5 col7" >0.7800</td>
#       <td id="T_f10a8_row5_col8" class="data row5 col8" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_f10a8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f10a8_row6_col0" class="data row6 col0" >windspeed</td>
#       <td id="T_f10a8_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_f10a8_row6_col2" class="data row6 col2" >0.1901</td>
#       <td id="T_f10a8_row6_col3" class="data row6 col3" >0.1223</td>
#       <td id="T_f10a8_row6_col4" class="data row6 col4" >0.0000</td>
#       <td id="T_f10a8_row6_col5" class="data row6 col5" >0.1045</td>
#       <td id="T_f10a8_row6_col6" class="data row6 col6" >0.1940</td>
#       <td id="T_f10a8_row6_col7" class="data row6 col7" >0.2537</td>
#       <td id="T_f10a8_row6_col8" class="data row6 col8" >0.8507</td>
#     </tr>
#     <tr>
#       <th id="T_f10a8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f10a8_row7_col0" class="data row7 col0" >cnt</td>
#       <td id="T_f10a8_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_f10a8_row7_col2" class="data row7 col2" >189.4631</td>
#       <td id="T_f10a8_row7_col3" class="data row7 col3" >181.3876</td>
#       <td id="T_f10a8_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_f10a8_row7_col5" class="data row7 col5" >40.0000</td>
#       <td id="T_f10a8_row7_col6" class="data row7 col6" >142.0000</td>
#       <td id="T_f10a8_row7_col7" class="data row7 col7" >281.0000</td>
#       <td id="T_f10a8_row7_col8" class="data row7 col8" >977.0000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_64bdf_row0_col0, #T_64bdf_row0_col1, #T_64bdf_row0_col2, #T_64bdf_row0_col3, #T_64bdf_row0_col4, #T_64bdf_row0_col5, #T_64bdf_row0_col6, #T_64bdf_row3_col0, #T_64bdf_row3_col1, #T_64bdf_row3_col2, #T_64bdf_row3_col3, #T_64bdf_row3_col4, #T_64bdf_row3_col5, #T_64bdf_row3_col6 {
#   background-color: grey;
# }
# </style>
# <table id="T_64bdf" style='display:inline'>
#   <caption>Categorical Attributes</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64bdf_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_64bdf_level0_col1" class="col_heading level0 col1" >n_missing</th>
#       <th id="T_64bdf_level0_col2" class="col_heading level0 col2" >n_unique</th>
#       <th id="T_64bdf_level0_col3" class="col_heading level0 col3" >top1</th>
#       <th id="T_64bdf_level0_col4" class="col_heading level0 col4" >top2</th>
#       <th id="T_64bdf_level0_col5" class="col_heading level0 col5" >top3</th>
#       <th id="T_64bdf_level0_col6" class="col_heading level0 col6" >n_others</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64bdf_level0_row0" class="row_heading level0 row0" >0</th>
# Data Shape:(17379, 13)

# %%
# Prepare dataset by setting target, task type and train-test split
exp.data_prepare(target='cnt', task_type='regression', test_ratio=0.2, random_state=0)
# Out:
#              Config                        Value
# 0  Excluded columns  [atemp, workingday, season]
# 1   Target variable                          cnt
# 2     Sample weight                         None
# 3         Task type                   regression
# 4      Split method                       random
# 5        Test ratio                          0.2
# 6      Random state                            0

# %%
# Optional: select features by LightGBM feature importance
exp.feature_select(threshold=0.98, method="pfi", figsize=(6, 5))

# %%
# Exploratory data analysis, check distribution and correlation
exp.eda(show='univariate', uni_feature='temp', figsize=(6, 5))

# %%
exp.eda(show='bivariate', bi_features=['hr', 'cnt'], figsize=(6, 5))

# %%
exp.eda(show='multivariate', multi_type='correlation_heatmap', figsize=(6, 5))

# %% [markdown]
# # Train intepretable models

# %%
## ReLU-DNN: ReLU Deep Neural Networks with L1-Regularization
from piml.models import ReluDNNRegressor

model1 = ReluDNNRegressor(hidden_layer_sizes=(40, 40), l1_reg=1e-05,
                        batch_size=500, learning_rate=0.001)
exp.model_train(model=model1, name='ReLU-DNN')
exp.model_diagnose(model="ReLU-DNN", show='accuracy_table')
# Out:
#           MSE     MAE       R2
#
# Train  0.0033  0.0379   0.9053
# Test   0.0037  0.0403   0.8940
# Gap    0.0005  0.0024  -0.0113

# %%
## GAMI-Net: GAM-Neural Networks with Structured Interactions
from piml.models import GAMINetRegressor

model2 = GAMINetRegressor(interact_num=10, loss_threshold=0.01,
                        subnet_size_main_effect=[20],
                        subnet_size_interaction=[20,20])
exp.model_train(model=model2, name='GAMI-Net')
exp.model_diagnose(model="GAMI-Net", show='accuracy_table')
# Out:
#           MSE     MAE       R2
#
# Train  0.0034  0.0394   0.9014
# Test   0.0037  0.0420   0.8932
# Gap    0.0003  0.0026  -0.0082

# %%
## EBM: Explainable Boosting Machine from MS Research
from piml.models import ExplainableBoostingRegressor

model3 = ExplainableBoostingRegressor(interactions=10, random_state=0)
exp.model_train(model=model3, name='EBM')
exp.model_diagnose(model="EBM", show='accuracy_table')

# %%
exp.model_compare(models=['ReLU-DNN', 'GAMI-Net', 'EBM'], show='accuracy_plot', metric="MSE", figsize=(6, 5))

# %% [markdown]
# # Explainability and Interpretability

# %% [markdown]
# ## Post-hoc Explainability: Global and Local Methods

# %%
exp.model_explain(model='GAMI-Net', show='pfi', figsize=(6, 5))

# %%
exp.model_explain(model='GAMI-Net', show='pdp', uni_feature='hr', figsize=(6, 5))

# %%
exp.model_explain(model='GAMI-Net', show='ice', uni_feature="hr", figsize=(6, 5))

# %%
exp.model_explain(model='GAMI-Net', show='ale', bi_features=['hr', 'weekday'], figsize=(6, 5))

# %%
exp.model_explain(model='GAMI-Net', show='shap_fi', sample_size=20, figsize=(6, 5))

# %%
exp.model_explain(model='GAMI-Net', show='shap_summary', sample_size=20, figsize=(6, 5))

# %%
exp.model_explain(model='GAMI-Net', show='shap_waterfall', sample_id=0, figsize=(6, 5))

# %%
exp.model_explain(model='GAMI-Net', show='lime', sample_id=0, figsize=(6, 5))

# %% [markdown]
# ## Inherent Interpretability: Global and Local Methods

# %%
exp.model_interpret(model='GAMI-Net', show='global_fi', figsize=(6, 5))

# %%
exp.model_interpret(model='GAMI-Net', show='global_effect_plot', uni_feature='hr', figsize=(6, 5))

# %%
exp.model_interpret(model='GAMI-Net', show='local_fi', sample_id=0, figsize=(6, 5))

# %% [markdown]
# # Model Diagnostics and Outcome Testing

# %%
exp.model_diagnose(model='GAMI-Net', show='accuracy_table')

# %%
exp.model_diagnose(model='GAMI-Net', show='accuracy_residual', show_feature='hr', figsize=(6, 5))

# %%
exp.model_diagnose(model='GAMI-Net', show='weakspot', slice_features=['hr'],
                   slice_method='tree', threshold=1.2, min_samples=20, figsize=(6, 5))

# %%
exp.model_diagnose(model='GAMI-Net', show='weakspot', slice_features=['hr', 'weekday'],
                   slice_method='histogram', threshold=1.2, min_samples=20, figsize=(6, 5))

# %%
exp.model_diagnose(model='GAMI-Net', show='weakspot', slice_features=['hr', 'weekday'], return_data=True,
                   slice_method='histogram', threshold=1.2, min_samples=20, figsize=(6, 5))

# %%
exp.model_diagnose(model='GAMI-Net', show='overfit', slice_features=['hr'],
                   slice_method='histogram', threshold=1.1, min_samples=20, figsize=(6, 5))

# %%
exp.model_diagnose(model='GAMI-Net', show='reliability_marginal', alpha=0.1,
                   show_feature='hr', threshold=1.2, bins=10, figsize=(6, 5))

# %%
exp.model_diagnose(model='GAMI-Net', show='robustness_perf', perturb_features=None, perturb_size=0.01, figsize=(6, 5))

# %%
exp.model_diagnose(model='GAMI-Net', show='resilience_perf', show_feature='hr', figsize=(6, 5))

# %%
exp.model_diagnose(model='GAMI-Net', show='resilience_shift_density', immu_feature='hr', show_feature='hr', alpha=0.2, figsize=(6, 5))

# %% [markdown]
# # Model Comparison and Benchmarking

# %%
exp.model_compare(models=['ReLU-DNN', 'GAMI-Net', 'EBM'], show='reliability_coverage', alpha=0.1, figsize=(6, 5))

# %%
exp.model_compare(models=['ReLU-DNN', 'GAMI-Net', 'EBM'], show='reliability_bandwidth', alpha=0.1, figsize=(6, 5))

# %%
exp.model_diagnose(model='ReLU-DNN', show='reliability_table', alpha=0.1, figsize=(6, 5))

# %%
exp.model_compare(models=['ReLU-DNN', 'GAMI-Net', 'EBM'], show='robustness_perf',
                  perturb_features=None, perturb_size=0.01, figsize=(6, 5))

# %%
exp.model_compare(models=['ReLU-DNN', 'GAMI-Net', 'EBM'], show='robustness_perf_worst',
                  perturb_features=None, perturb_size=0.01, alpha=0.2, figsize=(6, 5))

# %%
exp.model_compare(models=['ReLU-DNN', 'GAMI-Net', 'EBM'], show='resilience_perf', figsize=(6, 5))

# %%
exp.model_compare(models=['ReLU-DNN', 'GAMI-Net', 'EBM'], show='resilience_distance', figsize=(6, 5))
